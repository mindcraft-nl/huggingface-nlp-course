# %% [markdown]
# # What if my dataset isn't on the Hub?

# %% [markdown]
# Install the Transformers, Datasets, and Evaluate libraries to run this notebook.

# %%
# !pip install datasets evaluate transformers[sentencepiece]
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting datasets
#   Downloading datasets-2.12.0-py3-none-any.whl (474 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 474.6/474.6 kB 7.2 MB/s eta 0:00:00
# Collecting evaluate
#   Downloading evaluate-0.4.0-py3-none-any.whl (81 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.4/81.4 kB 4.9 MB/s eta 0:00:00
# Collecting transformers[sentencepiece]
#   Downloading transformers-4.29.1-py3-none-any.whl (7.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.1/7.1 MB 61.7 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from datasets) (1.22.4)
# Requirement already satisfied: pyarrow>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (9.0.0)
# Collecting dill<0.3.7,>=0.3.0 (from datasets)
#   Downloading dill-0.3.6-py3-none-any.whl (110 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.5/110.5 kB 6.1 MB/s eta 0:00:00
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets) (1.5.3)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (2.27.1)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (4.65.0)
# Collecting xxhash (from datasets)
#   Downloading xxhash-3.2.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (212 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 212.5/212.5 kB 7.6 MB/s eta 0:00:00
# Collecting multiprocess (from datasets)
#   Downloading multiprocess-0.70.14-py310-none-any.whl (134 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.3/134.3 kB 2.0 MB/s eta 0:00:00
# Requirement already satisfied: fsspec[http]>=2021.11.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (2023.4.0)
# Collecting aiohttp (from datasets)
#   Downloading aiohttp-3.8.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 21.5 MB/s eta 0:00:00
# Collecting huggingface-hub<1.0.0,>=0.11.0 (from datasets)
#   Downloading huggingface_hub-0.14.1-py3-none-any.whl (224 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.5/224.5 kB 10.6 MB/s eta 0:00:00
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from datasets) (23.1)
# Collecting responses<0.19 (from datasets)
#   Downloading responses-0.18.0-py3-none-any.whl (38 kB)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (6.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers[sentencepiece]) (3.12.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers[sentencepiece]) (2022.10.31)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1 (from transformers[sentencepiece])
#   Downloading tokenizers-0.13.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 48.4 MB/s eta 0:00:00
# Collecting sentencepiece!=0.1.92,>=0.1.91 (from transformers[sentencepiece])
#   Downloading sentencepiece-0.1.99-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 3.8 MB/s eta 0:00:00
# Collecting protobuf<=3.20.2 (from transformers[sentencepiece])
#   Downloading protobuf-3.20.2-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 13.0 MB/s eta 0:00:00
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (23.1.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (2.0.12)
# Collecting multidict<7.0,>=4.5 (from aiohttp->datasets)
#   Downloading multidict-6.0.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (114 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.5/114.5 kB 1.7 MB/s eta 0:00:00
# Collecting async-timeout<5.0,>=4.0.0a3 (from aiohttp->datasets)
#   Downloading async_timeout-4.0.2-py3-none-any.whl (5.8 kB)
# Collecting yarl<2.0,>=1.0 (from aiohttp->datasets)
#   Downloading yarl-1.9.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (268 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 13.8 MB/s eta 0:00:00
# Collecting frozenlist>=1.1.1 (from aiohttp->datasets)
#   Downloading frozenlist-1.3.3-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (149 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 149.6/149.6 kB 6.1 MB/s eta 0:00:00
# Collecting aiosignal>=1.1.2 (from aiohttp->datasets)
#   Downloading aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0.0,>=0.11.0->datasets) (4.5.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (3.4)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2022.7.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->datasets) (1.16.0)
# Installing collected packages: tokenizers, sentencepiece, xxhash, protobuf, multidict, frozenlist, dill, async-timeout, yarl, responses, multiprocess, huggingface-hub, aiosignal, transformers, aiohttp, datasets, evaluate
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.20.3
#     Uninstalling protobuf-3.20.3:
#       Successfully uninstalled protobuf-3.20.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow 2.12.0 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3, but you have protobuf 3.20.2 which is incompatible.
# tensorflow-metadata 1.13.1 requires protobuf<5,>=3.20.3, but you have protobuf 3.20.2 which is incompatible.
# Successfully installed aiohttp-3.8.4 aiosignal-1.3.1 async-timeout-4.0.2 datasets-2.12.0 dill-0.3.6 evaluate-0.4.0 frozenlist-1.3.3 huggingface-hub-0.14.1 multidict-6.0.4 multiprocess-0.70.14 protobuf-3.20.2 responses-0.18.0 sentencepiece-0.1.99 tokenizers-0.13.3 transformers-4.29.1 xxhash-3.2.0 yarl-1.9.2

# %%
# !wget https://github.com/crux82/squad-it/raw/master/SQuAD_it-train.json.gz
# !wget https://github.com/crux82/squad-it/raw/master/SQuAD_it-test.json.gz
# Out:
# --2023-05-16 16:41:35--  https://github.com/crux82/squad-it/raw/master/SQuAD_it-train.json.gz
# Resolving github.com (github.com)... 140.82.113.4
# Connecting to github.com (github.com)|140.82.113.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/crux82/squad-it/master/SQuAD_it-train.json.gz [following]
# --2023-05-16 16:41:36--  https://raw.githubusercontent.com/crux82/squad-it/master/SQuAD_it-train.json.gz
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 7725286 (7.4M) [application/octet-stream]
# Saving to: ‘SQuAD_it-train.json.gz’
#
# SQuAD_it-train.json 100%[===================>]   7.37M  --.-KB/s    in 0.09s
#
# 2023-05-16 16:41:36 (80.4 MB/s) - ‘SQuAD_it-train.json.gz’ saved [7725286/7725286]
#
# --2023-05-16 16:41:36--  https://github.com/crux82/squad-it/raw/master/SQuAD_it-test.json.gz
# Resolving github.com (github.com)... 140.82.113.4
# Connecting to github.com (github.com)|140.82.113.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/crux82/squad-it/master/SQuAD_it-test.json.gz [following]
# --2023-05-16 16:41:36--  https://raw.githubusercontent.com/crux82/squad-it/master/SQuAD_it-test.json.gz
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.108.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1051245 (1.0M) [application/octet-stream]
# Saving to: ‘SQuAD_it-test.json.gz’
#
# SQuAD_it-test.json. 100%[===================>]   1.00M  --.-KB/s    in 0.06s
#
# 2023-05-16 16:41:36 (17.3 MB/s) - ‘SQuAD_it-test.json.gz’ saved [1051245/1051245]

# %%
# !gzip -dkv SQuAD_it-*.json.gz
# Out:
# SQuAD_it-test.json.gz:	 87.5% -- created SQuAD_it-test.json
# SQuAD_it-train.json.gz:	 82.3% -- created SQuAD_it-train.json

# %%
from datasets import load_dataset

squad_it_dataset = load_dataset("json", data_files="SQuAD_it-train.json", field="data")
# Out:
# Downloading and preparing dataset json/default to /root/.cache/huggingface/datasets/json/default-df8051a3a0d1e9f8/0.0.0/e347ab1c932092252e717ff3f949105a4dd28b27e842dd53157d2f72e276c2e4...
# Downloading data files:   0%|          | 0/1 [00:00<?, ?it/s]
# Extracting data files:   0%|          | 0/1 [00:00<?, ?it/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# Dataset json downloaded and prepared to /root/.cache/huggingface/datasets/json/default-df8051a3a0d1e9f8/0.0.0/e347ab1c932092252e717ff3f949105a4dd28b27e842dd53157d2f72e276c2e4. Subsequent calls will reuse this data.
#   0%|          | 0/1 [00:00<?, ?it/s]

# %%
squad_it_dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['paragraphs', 'title'],
#         num_rows: 442
#     })
# })

# %%
squad_it_dataset["train"][300]
# Out:
# {'paragraphs': [{'context': 'La carta è un materiale sottile ottenuto dalla pressatura di fibre umide di cellulosa derivate da legno, stracci o erbe, e dalla loro essiccazione in fogli flessibili. Si tratta di un materiale versatile con molti usi, tra cui scrittura, stampa, imballaggio, pulizia e una serie di processi industriali e di costruzione.',
#    'qas': [{'answers': [{'answer_start': 98, 'text': 'legno'}],
#      'id': '56e678026fe0821900b8ea3b',
#      'question': 'Qual è la fonte delle particelle di carta?'},
#     {'answers': [{'answer_start': 227, 'text': 'scrittura'}],
#      'id': '56e678026fe0821900b8ea3c',
#      'question': "Qual è l' uso comune della carta?"},
#     {'answers': [{'answer_start': 134, 'text': 'essiccazione'}],
#      'id': '56e678026fe0821900b8ea3e',
#      'question': "Qual è l' ultimo passo nella produzione della carta?"}]},
#   {'context': "Si dice che il processo di produzione della pasta di cellulosa sia stato sviluppato in Cina all' inizio del II secolo d. C., forse già nel 105 d.",
#    'qas': [{'answers': [{'answer_start': 87, 'text': 'Cina'}],
#      'id': '56e7460a00c9c71400d76f10',
#      'question': 'In quale paese si è sviluppato il processo?'},
#     {'answers': [{'answer_start': 87, 'text': 'Cina'}],
#      'id': '56e7460a00c9c71400d76f11',
#      'question': 'Quale paese è leader nella produzione di carta?'}]},
#   {'context': "I più antichi frammenti archeologici conosciuti dell' immediato precursore della carta moderna, risalgono al 2 ° secolo aC in Cina. Il processo di fabbricazione della pasta di cellulosa è attribuito a Cai Lun, un eunuch di corte del II secolo AD Han. Con la carta come efficace sostituto della seta in molte applicazioni, la Cina potrebbe esportare la seta in maggiore quantità, contribuendo all' età dell' oro.",
#    'qas': [{'answers': [{'answer_start': 201, 'text': 'Cai Lun'}],
#      'id': '56e746fc00c9c71400d76f19',
#      'question': 'A chi è accreditato il processo di fabbricazione della carta?'},
#     {'answers': [{'answer_start': 294, 'text': 'seta'}],
#      'id': '56e746fc00c9c71400d76f1b',
#      'question': 'Quale materiale sostituiva la carta alla sua invenzione?'}]},
#   {'context': "Le sue conoscenze e i suoi usi si diffuse dalla Cina attraverso il Medio Oriente fino all' Europa medievale nel XIII secolo, dove furono costruite le prime cartiere ad acqua. A causa dell' introduzione della carta all' Occidente attraverso la città di Baghdad, è stato chiamato prima bagdatikos. Nel XIX secolo, la produzione industriale ha notevolmente ridotto i suoi costi, consentendo lo scambio di massa di informazioni e contribuendo a significativi cambiamenti culturali. Nel 1844, l' inventore canadese Charles Fenerty e il tedesco F. G. Keller svilupparono in modo indipendente i processi per la macero delle fibre di legno.",
#    'qas': [{'answers': [{'answer_start': 252, 'text': 'Baghdad'}],
#      'id': '56e74a8e00c9c71400d76f5c',
#      'question': 'Da quale città mediorientale è avvenuto il processo di produzione della carta in Europa?'},
#     {'answers': [{'answer_start': 284, 'text': 'bagdatikos'}],
#      'id': '56e74a8e00c9c71400d76f5d',
#      'question': 'Quale nome ha assunto il processo a Baghdad?'},
#     {'answers': [{'answer_start': 510, 'text': 'Charles Fenerty'}],
#      'id': '56e74a8e00c9c71400d76f5f',
#      'question': 'Quale inventore canadese ha aiutato F. G. Keller a sviluppare il proprio processo?'}]},
#   {'context': 'La parola "carta" deriva etimologicamente dal papiro latino, che viene dal greco????? (papuros), la parola per la pianta papiro cipriota. Papiro è un materiale spesso, carta-come prodotto dal midollo della pianta papiro cipriota, che è stato utilizzato nell\' antico Egitto e in altre culture mediterranee per scrivere prima dell\' introduzione della carta in Medio Oriente e in Europa. Anche se la parola carta è etimologicamente derivato da papiro, i due sono prodotti in modo molto diverso e lo sviluppo del primo è distinto dallo sviluppo del secondo. Il papiro è una laminazione di fibre vegetali naturali, mentre la carta è prodotta a partire da fibre le cui proprietà sono state modificate dalla macerazione.',
#    'qas': [{'answers': [{'answer_start': 46, 'text': 'Papiro'}],
#      'id': '56e74b6037bdd419002c3e1f',
#      'question': 'Da quale parola latina deriva la carta?'},
#     {'answers': [{'answer_start': 75, 'text': 'greco'}],
#      'id': '56e74b6037bdd419002c3e20',
#      'question': 'Da quale lingua deriva il papiro?'},
#     {'answers': [{'answer_start': 701, 'text': 'macerazione'}],
#      'id': '56e74b6037bdd419002c3e21',
#      'question': 'Quale processo modifica le proprietà delle fibre utilizzate nella fabbricazione della carta?'}]},
#   {'context': 'Per produrre pasta di legno, un processo chimico separa la lignina dalle fibre di cellulosa. Ciò si ottiene sciogliendo la lignina in un bagno di cottura, in modo che possa essere lavata dalla cellulosa, preservando così la lunghezza delle fibre di cellulosa. La carta prodotta con pasta di carta chimica è nota anche come carta senza legno, da non confondere con la carta senza alberi, perché non contiene lignina, che si deteriora nel tempo. La polpa può anche essere sbiancata per produrre carta bianca, ma consuma il 5% delle fibre; i processi chimici di macero non vengono utilizzati per produrre carta a base di cotone, che è già al 90% cellulosa.',
#    'qas': [{'answers': [{'answer_start': 59, 'text': 'lignina'}],
#      'id': '56e74d4a37bdd419002c3e3d',
#      'question': 'Che cosa è separato dalle fibre di cellulosa?'},
#     {'answers': [{'answer_start': 329, 'text': 'senza legno'}],
#      'id': '56e74d4a37bdd419002c3e3e',
#      'question': 'Qual è il tipo di carta a base di pasta di carta chimica nota come carta?'},
#     {'answers': [{'answer_start': 521, 'text': '5%'}],
#      'id': '56e74d4a37bdd419002c3e40',
#      'question': 'Qual è la percentuale di fibre sprecate nel processo di sbiancamento?'},
#     {'answers': [{'answer_start': 639, 'text': '90%'}],
#      'id': '56e74d4a37bdd419002c3e41',
#      'question': 'Quale percentuale di cotone è cellulosa?'}]},
#   {'context': "Ci sono tre principali processi chimici: il processo sulfita risale al 1840 ed era il metodo dominante prima della seconda guerra mondiale. Il processo kraft, inventato nel 1870 e utilizzato per la prima volta nel 1890, è oggi la strategia più comunemente praticata, uno dei suoi vantaggi è la reazione chimica con la lignina, che produce calore, che può essere utilizzato per far funzionare un generatore. La maggior parte delle operazioni di macero che utilizzano il processo kraft sono contribuenti netti alla rete elettrica o utilizzano l' elettricità per far funzionare una cartiera adiacente. Un altro vantaggio è che questo processo recupera e riutilizza tutti i reagenti chimici inorganici. La pasta di pasta di soda è un' altra specialità utilizzata per la polpa di paglia, bagassa e legno duro ad alto contenuto di silicato.",
#    'qas': [{'answers': [{'answer_start': 8, 'text': 'tre'}],
#      'id': '56e74eaf00c9c71400d76f80',
#      'question': 'Quanti processi chimici di macerazione esistono?'},
#     {'answers': [{'answer_start': 140, 'text': 'Il processo kraft'}],
#      'id': '56e74eaf00c9c71400d76f82',
#      'question': 'Qual è il processo più comunemente utilizzato?'},
#     {'answers': [{'answer_start': 711, 'text': 'pasta di soda'}],
#      'id': '56e74eaf00c9c71400d76f84',
#      'question': 'Qual è un altro processo utilizzato per la polpa di paglia ad alto contenuto di silicato?'}]},
#   {'context': "Ci sono due principali paste meccaniche, quella termomeccanica (TMP) e la pasta di legno macinato (GW). Nel processo TMP, il legno viene scheggiato e poi immesso in grandi raffinerie riscaldate a vapore, dove i trucioli vengono spremuti e trasformati in fibre tra due dischi d' acciaio. Nel processo di macinazione del legno, i tronchi scortecciati vengono alimentati in rettificatrici dove vengono pressati contro pietre rotanti da trasformare in fibre. La pasta di carta meccanica non rimuove la lignina, quindi il rendimento è molto elevato, >95%, ma fa sì che la carta così prodotta si ingiallisse e diventa fragile nel tempo. Le paste meccaniche hanno fibre piuttosto corte, producendo così carta debole. Sebbene per produrre pasta meccanica siano necessarie grandi quantità di energia elettrica, essa costa meno del tipo chimico.",
#    'qas': [{'answers': [{'answer_start': 74,
#        'text': 'pasta di legno macinato'}],
#      'id': '56e74f5300c9c71400d76f8a',
#      'question': "Oltre al processo termomeccanico, che cos' è un processo utilizzato nella macerazione?"},
#     {'answers': [{'answer_start': 328, 'text': 'tronchi scortecciati'}],
#      'id': '56e74f5300c9c71400d76f8b',
#      'question': "Qual è l' ingrediente principale nel processo di macinazione del legno?"},
#     {'answers': [{'answer_start': 702, 'text': 'debole'}],
#      'id': '56e74f5300c9c71400d76f8c',
#      'question': 'Qual è la forza della carta prodotta dalle paste meccaniche?'}]},
#   {'context': "Le carte riciclate possono essere realizzate con materiali riciclati al 100% o miscelate con pasta vergine, anche se non sono (generalmente) così resistenti e brillanti come le carte di quest' ultima.",
#    'qas': [{'answers': [{'answer_start': 99, 'text': 'vergine'}],
#      'id': '56e7521e37bdd419002c3e69',
#      'question': 'Le carte riciclate possono essere realizzate con quale nuovo tipo di pasta?'}]},
#   {'context': "Oltre alle fibre, la pasta di carta può contenere cariche come gesso o argilla di porcellana, che ne migliorano le caratteristiche di stampa o scrittura. Gli additivi per la calibratura possono essere mescolati con esso e/o applicati sul nastro di carta in una fase successiva del processo di fabbricazione; lo scopo di tale calibratura è quello di stabilire il livello corretto di assorbimento della superficie per adattarsi all' inchiostro o alla vernice.",
#    'qas': [{'answers': [{'answer_start': 71, 'text': 'argilla di porcellana'}],
#      'id': '56e753fb37bdd419002c3e81',
#      'question': 'Che tipo di argilla migliora le caratteristiche delle paste utilizzate nella fabbricazione della carta?'},
#     {'answers': [{'answer_start': 158, 'text': 'additivi'}],
#      'id': '56e753fb37bdd419002c3e82',
#      'question': 'Cosa viene aggiunto per il dimensionamento?'},
#     {'answers': [{'answer_start': 63, 'text': 'gesso'}],
#      'id': '56e753fb37bdd419002c3e84',
#      'question': "Oltre all' argilla di porcellana, che cosa viene usato come riempitivo?"}]},
#   {'context': "Premendo il foglio si rimuove l' acqua con la forza; una volta forzata l' acqua dal foglio, per raccogliere l' acqua viene utilizzato un particolare tipo di feltro, da non confondere con quello tradizionale; mentre quando si fa carta a mano si usa invece un foglio di carta assorbente.",
#    'qas': [{'answers': [{'answer_start': 0, 'text': 'Premendo'}],
#      'id': '56e758c700c9c71400d76fe4',
#      'question': "Come viene rimossa con la forza l' acqua da un foglio di carta?"},
#     {'answers': [{'answer_start': 157, 'text': 'feltro'}],
#      'id': '56e758c700c9c71400d76fe5',
#      'question': "Cosa serve per raccogliere l' acqua espulsa dalla pressatura?"},
#     {'answers': [{'answer_start': 157, 'text': 'feltro'}],
#      'id': '56e758c700c9c71400d76fe7',
#      'question': "Oltre ad un telo di tamponamento, cosa si può usare per raccogliere l' acqua?"}]},
#   {'context': "L' essiccazione comporta l' uso di aria e/o calore per rimuovere l' acqua dai fogli di carta; nei primi giorni della produzione della carta questo è stato fatto appendendo i fogli come lavanderia; in tempi più moderni si utilizzano varie forme di essiccazione riscaldate. Sulla macchina continua la più comune è l' asciugatrice a vapore riscaldata. Questi possono raggiungere temperature superiori a 200 °F (93 °C) e sono utilizzati in lunghe sequenze di oltre 40 lattine; dove il calore prodotto da questi può facilmente asciugare la carta a meno del 6% di umidità.",
#    'qas': [{'answers': [{'answer_start': 35, 'text': 'aria'}],
#      'id': '56e759ac37bdd419002c3ebd',
#      'question': "Qual è il componente principale dell' essiccazione della carta?"},
#     {'answers': [{'answer_start': 552, 'text': '6'}],
#      'id': '56e759ac37bdd419002c3ec1',
#      'question': 'A quale percentuale il processo di fabbricazione della carta sta cercando di raggiungere alla fine?'}]},
#   {'context': "La carta a questo punto non è patinata. La carta patinata ha uno strato sottile di materiale come il carbonato di calcio o l' argilla di porcellana applicata su uno o entrambi i lati per creare una superficie più adatta per gli schermi mezzitoni ad alta risoluzione. (Le carte non patinate sono raramente adatte per schermi superiori a 150 lpi.) Le carte patinate o non patinate possono essere lucidate con la calandratura. Le carte patinate sono divise in opaco, semi mat o seta e lucido. Le carte lucide offrono la massima densità ottica nell' immagine stampata.",
#    'qas': [{'answers': [{'answer_start': 126,
#        'text': 'argilla di porcellana'}],
#      'id': '56e75b5300c9c71400d77006',
#      'question': 'Oltre al calcio, la carta patinata ha uno strato sottile di che cosa?'},
#     {'answers': [{'answer_start': 410, 'text': 'calandratura'}],
#      'id': '56e75b5300c9c71400d77008',
#      'question': 'Che cosa si fa per lucidare la superficie della carta?'}]},
#   {'context': 'La carta viene quindi caricata sulle bobine se deve essere utilizzata su macchine da stampa a bobina, oppure tagliata in fogli per altri processi di stampa o altri scopi. Le fibre della carta scorrono fondamentalmente nella direzione della macchina. I fogli sono di solito tagliati "a grana lunga", cioè con la grana parallela alla dimensione più lunga del foglio. bobine.',
#    'qas': []},
#   {'context': 'Tutta la carta prodotta dalle macchine da stampa come le Fourdrinier Machine è carta grezza, cioè la rete metallica che trasporta il nastro lascia uno schema che ha la stessa densità lungo la grana della carta e attraverso la grana. Finiture strutturate, filigrane e disegni di fili che imitano la carta stesa fatta a mano possono essere creati utilizzando appositi rulli nelle fasi successive della macchina. carta traforata.',
#    'qas': [{'answers': [{'answer_start': 175, 'text': 'densità'}],
#      'id': '56e75d7100c9c71400d77011',
#      'question': "Che cosa c' è in comune con la quaresima lungo e attraverso la grana di carta prodotta da una macchina come la Fourdrinier?"},
#     {'answers': [{'answer_start': 101, 'text': 'rete metallica'}],
#      'id': '56e75d7100c9c71400d77012',
#      'question': 'Che cosa lascia un modello sulla carta che ha una densità costante di larghezza e lunghezza?'}]},
#   {'context': 'La carta Wove non presenta linee "posate", che sono piccole linee regolari lasciate sulla carta quando è stata fatta a mano in uno stampo fatto da file di fili metallici o bambù. Le linee guida sono molto vicine. Corrono perpendicolarmente alle "linee di catena", che sono più distanti. La carta fatta a mano presenta anche i "bordi di coperta", o bordi ruvidi e piume.',
#    'qas': [{'answers': [{'answer_start': 182, 'text': 'linee guida'}],
#      'id': '56e75e1200c9c71400d77018',
#      'question': 'Che tipo di linee non mostra la carta traforata?'},
#     {'answers': [{'answer_start': 182, 'text': 'linee guida'}],
#      'id': '56e75e1200c9c71400d77019',
#      'question': 'Quali sono le piccole righe regolari lasciate sulla carta quando fatte a mano in uno stampo?'},
#     {'answers': [{'answer_start': 182, 'text': 'linee guida'}],
#      'id': '56e75e1200c9c71400d7701c',
#      'question': 'Che cosa sono le linee sono comunemente più alte in densità, linee di posa o linee di catena?'}]},
#   {'context': 'Lo spessore della carta è spesso misurato dal calibro, che è tipicamente dato in millesimi di pollice negli Stati Uniti e in millesimi di mm nel resto del mondo. La carta può avere uno spessore compreso tra 0,07 e 0,18 mm (0,0028 e 0,0071 in).',
#    'qas': [{'answers': [{'answer_start': 46, 'text': 'calibro'}],
#      'id': '56e75f4b37bdd419002c3f09',
#      'question': 'Quale strumento viene spesso utilizzato per misurare lo spessore della carta?'},
#     {'answers': [{'answer_start': 81, 'text': 'millesimi di pollice'}],
#      'id': '56e75f4b37bdd419002c3f0a',
#      'question': 'Negli Stati Uniti, quali unità vengono utilizzate per indicare le misure dello spessore della carta?'},
#     {'answers': [{'answer_start': 138, 'text': 'mm'}],
#      'id': '56e75f4b37bdd419002c3f0b',
#      'question': 'Qualcuno che misura lo spessore della carta nel Regno Unito probabilmente utilizzerà quale unità?'},
#     {'answers': [{'answer_start': 223, 'text': '0,0028 e 0,0071 in'}],
#      'id': '56e75f4b37bdd419002c3f0d',
#      'question': 'In pollici, qual è la gamma comune di spessore della carta?'}]},
#   {'context': 'La carta è spesso caratterizzata dal peso. Negli Stati Uniti, il peso assegnato ad una carta è il peso di una risma, 500 fogli, di "formati base"variabili, prima che la carta venga tagliata nel formato in cui è venduta ai clienti finali. Ad esempio, una risma di carta da 20 libbre, 8,5 pollici × 11 pollici (216 mm × 279 mm) pesa 5 libbre, perché è stata tagliata da un foglio più grande in quattro pezzi. Negli Stati Uniti, la carta da stampa è generalmente 20 libbre, 24 libbre o 32 libbre al massimo. Lo stock di copertine è generalmente di 68 libbre e 110 libbre o più è considerato lo stock di carte.',
#    'qas': [{'answers': [{'answer_start': 37, 'text': 'peso'}],
#      'id': '56e7601000c9c71400d77044',
#      'question': 'A che caratteristica è la carta di solito classificata?'},
#     {'answers': [{'answer_start': 106, 'text': 'una risma'}],
#      'id': '56e7601000c9c71400d77045',
#      'question': 'Negli Stati Uniti, il peso di ciò che viene usato per classificare la carta in vendita?'}]},
#   {'context': 'In Europa, e in altre regioni che utilizzano il sistema di calibratura della carta ISO 216, il peso è espresso in grammi per metro quadrato (g/m2 o solitamente solo g) della carta. La carta da stampa è generalmente compresa tra 60 g e 120 g. Qualsiasi cosa più pesante di 160 g è considerata carta. Il peso di una risma dipende quindi dalle dimensioni della carta e dal suo spessore.',
#    'qas': [{'answers': [{'answer_start': 83, 'text': 'ISO 216'}],
#      'id': '56e7621400c9c71400d77068',
#      'question': "Quale sistema di dimensionamento ISO utilizza l' Europa?"},
#     {'answers': [{'answer_start': 341, 'text': 'dimensioni'}],
#      'id': '56e7621400c9c71400d7706c',
#      'question': 'Oltre allo spessore, quale attributo viene utilizzato per indicare il peso di una risma in Europa?'}]},
#   {'context': 'La maggior parte della carta commerciale venduta nel Nord America è tagliata in formati standard basati sulle unità abituali ed è definita dalla lunghezza e larghezza di un foglio di carta.',
#    'qas': [{'answers': [{'answer_start': 145,
#        'text': 'lunghezza e larghezza'}],
#      'id': '56e7627c37bdd419002c3f1d',
#      'question': 'La carta commerciale è comunemente definita da cosa?'},
#     {'answers': [{'answer_start': 145, 'text': 'lunghezza e larghezza'}],
#      'id': '56e7627c37bdd419002c3f1f',
#      'question': 'I formati carta standard sono di solito descritti con quali termini?'}]},
#   {'context': "Il sistema ISO 216 utilizzato nella maggior parte degli altri paesi si basa sulla superficie di un foglio di carta, non sulla larghezza e lunghezza di un foglio. E' stato adottato per la prima volta in Germania nel 1922 e generalmente diffuso come nazioni hanno adottato il sistema metrico. La carta di formato standard più grande è A0 (A zero) e misura un metro quadrato (circa 1 metro quadrato). 1189 × 841 mm. Due fogli di A1, posti l' uno accanto all' altro, si inseriscono esattamente in un foglio di A0 posto sul fianco. Allo stesso modo, due fogli di A2 si inseriscono in un foglio di A1 e così via. Le dimensioni comuni utilizzate in ufficio e nella casa sono A4 e A3 (A3 è il formato di due fogli A4).",
#    'qas': [{'answers': [{'answer_start': 11, 'text': 'ISO 216'}],
#      'id': '56e7632700c9c71400d7707c',
#      'question': 'La maggior parte dei paesi oltre agli Stati Uniti utilizzano il sistema ISO?'},
#     {'answers': [{'answer_start': 202, 'text': 'Germania'}],
#      'id': '56e7632700c9c71400d7707d',
#      'question': 'Quale paese ha adottato per primo la norma ISO 216?'},
#     {'answers': [{'answer_start': 333, 'text': 'A0'}],
#      'id': '56e7632700c9c71400d7707e',
#      'question': 'Qual è il formato carta standard più grande?'},
#     {'answers': [{'answer_start': 15, 'text': '2'}],
#      'id': '56e7632700c9c71400d7707f',
#      'question': 'Quanti fogli di carta A1 coprirebbero un singolo pezzo di carta A0?'},
#     {'answers': [{'answer_start': 673, 'text': 'A3'}],
#      'id': '56e7632700c9c71400d77080',
#      'question': 'Qual è la carta A più bassa numerata che viene comunemente usata a casa?'}]},
#   {'context': 'La densità della carta varia da 250 kg/m3 (16 lb/cu ft) per la carta tissue a 1.500 kg/m3 (94 lb/cu ft) per alcuni tipi di carta speciale. La carta da stampa è di circa 800 kg/m3 (50 lb/cu ft).',
#    'qas': [{'answers': [{'answer_start': 169, 'text': '800 kg/m3'}],
#      'id': '56e763f737bdd419002c3f2e',
#      'question': 'Qual è la densità comune della carta da stampa?'}]},
#   {'context': 'Gran parte della prima carta ottenuta dalla pasta di legno conteneva quantità significative di allume, una varietà di sali di solfato di alluminio significativamente acidi. L\' allume è stato aggiunto alla carta per facilitarne il dimensionamento, rendendolo un po\' impermeabile in modo che gli inchiostri non "funzionino" o si diffondano in modo incontrollabile. I primi produttori di carta non si sono resi conto che l\' allume che hanno aggiunto liberalmente per curare quasi tutti i problemi incontrati nel fare il loro prodotto alla fine sarebbe dannoso. Le fibre di cellulosa che compongono la carta sono idrolizzate dall\' acido, e la presenza di allume alla fine degraderebbe le fibre fino a quando la carta si disintegra in un processo che è diventato noto come "fuoco lento". I documenti scritti su carta stracciata erano molto più stabili. L\' uso di additivi non acidi per la fabbricazione della carta sta diventando sempre più diffuso e la stabilità di questi documenti è meno problematica.',
#    'qas': [{'answers': [{'answer_start': 95, 'text': 'allume'}],
#      'id': '56e7650200c9c71400d77098',
#      'question': 'Quali sali acidi sono stati comunemente trovati nei primi tipi di carta prodotti?'}]},
#   {'context': "La carta di cellulosa meccanica contiene quantità significative di lignina, un componente importante del legno. In presenza di luce e ossigeno, la lignina reagisce per dare materiali gialli, ed è per questo che carta da giornale e altri gialli di carta meccanica con l' età. La carta ottenuta da carta kraft sbiancata o polpe di solfito non contiene quantità significative di lignina ed è quindi più adatta per libri, documenti e altre applicazioni in cui la bianchezza della carta è essenziale.",
#    'qas': [{'answers': [{'answer_start': 67, 'text': 'lignina'}],
#      'id': '56e765dc37bdd419002c3f36',
#      'question': "Quale particella è associata all' ingiallimento dei giornali?"},
#     {'answers': [{'answer_start': 67, 'text': 'lignina'}],
#      'id': '56e765dc37bdd419002c3f38',
#      'question': 'Un libro è probabilmente fatto con carta che ha basse quantità di quale componente del legno?'},
#     {'answers': [{'answer_start': 127, 'text': 'luce e ossigeno'}],
#      'id': '56e765dc37bdd419002c3f39',
#      'question': "Che cosa reagisce la lignina per produrre l' ingiallimento che vedete sui giornali?"}]},
#   {'context': "La carta ottenuta dalla pasta di legno non è necessariamente meno durevole della carta stracciata. Il comportamento all' invecchiamento di una carta è determinato dalla sua fabbricazione, non dalla fonte originale delle fibre. Inoltre, i test sponsorizzati dalla Biblioteca del Congresso dimostrano che tutta la carta è a rischio di decomposizione acida, perché la cellulosa stessa produce acidi formici, acetici, lattici e ossalici.",
#    'qas': [{'answers': [{'answer_start': 263,
#        'text': 'Biblioteca del Congresso'}],
#      'id': '56e7671700c9c71400d770b9',
#      'question': 'Chi ha sponsorizzato i test che dimostrano che tutte le carte sono soggette al decadimento acido?'}]},
#   {'context': 'La pasta meccanica produce quasi una tonnellata di pasta per tonnellata di legno secco utilizzato, motivo per cui la pasta meccanica viene talvolta definita "ad alto rendimento". Con un rendimento quasi doppio rispetto alla pasta chimica, le paste meccaniche sono spesso più economiche. I libri tascabili e i giornali di massa tendono ad utilizzare carta da stampa meccanica. Gli editori di libri tendono ad utilizzare carta priva di acidi, prodotta con paste chimiche completamente sbiancate per libri cartonati e libri in brossura.',
#    'qas': []},
#   {'context': 'Negli ultimi 40 anni, il consumo mondiale di carta è aumentato del 400%, con un conseguente aumento della deforestazione: il 35% degli alberi raccolti è stato utilizzato per la fabbricazione della carta. La maggior parte delle aziende cartarie anche piantare alberi per aiutare a ricrescere le foreste. Il disboscamento delle vecchie foreste di crescita rappresenta meno del 10 per cento della pasta di legno, ma è una delle questioni più controverse.',
#    'qas': [{'answers': [{'answer_start': 67, 'text': '400%'}],
#      'id': '56e768a600c9c71400d770d4',
#      'question': 'Negli ultimi 40 anni, quanto è aumentato il consumo mondiale di carta?'},
#     {'answers': [{'answer_start': 125, 'text': '35%'}],
#      'id': '56e768a600c9c71400d770d5',
#      'question': 'Quale percentuale di alberi raccolti viene utilizzata nella produzione della carta?'},
#     {'answers': [{'answer_start': 250, 'text': 'piantare alberi'}],
#      'id': '56e768a600c9c71400d770d6',
#      'question': 'Che cosa fanno molte aziende cartarie per garantire la salute delle foreste?'}]},
#   {'context': "I rifiuti di carta rappresentano fino al 40% dei rifiuti totali prodotti negli Stati Uniti ogni anno, che ammontano a 71,6 milioni di tonnellate di carta all' anno solo negli Stati Uniti. L' impiegato medio negli Stati Uniti stampa 31 pagine ogni giorno. Anche gli americani usano circa 16 miliardi di bicchieri di carta all' anno.",
#    'qas': [{'answers': [{'answer_start': 41, 'text': '40%'}],
#      'id': '56e7691537bdd419002c3f6d',
#      'question': 'Quale percentuale dei rifiuti totali può essere attribuita alla carta?'},
#     {'answers': [{'answer_start': 118, 'text': '71,6 milioni'}],
#      'id': '56e7691537bdd419002c3f6e',
#      'question': 'Quanti milioni di tonnellate di carta vengono sprecate ogni anno negli Stati Uniti?'},
#     {'answers': [{'answer_start': 287, 'text': '16 miliardi'}],
#      'id': '56e7691537bdd419002c3f6f',
#      'question': 'Quante tazze di carta vengono utilizzate ogni anno dagli americani?'},
#     {'answers': [{'answer_start': 232, 'text': '31'}],
#      'id': '56e7691537bdd419002c3f70',
#      'question': 'Quante pagine vengono stampate ogni giorno dal medio impiegato negli Stati Uniti?'}]},
#   {'context': "Lo sbiancamento convenzionale della pasta di legno con cloro elementare produce e rilascia nell' ambiente grandi quantità di composti organici clorurati, comprese le diossine clorurate. Le diossine sono riconosciute come inquinanti ambientali persistenti, disciplinati a livello internazionale dalla Convenzione di Stoccolma sugli inquinanti organici persistenti. Le diossine sono altamente tossiche e gli effetti sulla salute umana comprendono problemi riproduttivi, di sviluppo, immunitari e ormonali. Sono noti per essere cancerogeni. Oltre il 90% dell' esposizione umana è dovuta agli alimenti, principalmente carne, latticini, pesci e crostacei, in quanto le diossine si accumulano nella catena alimentare nel tessuto adiposo degli animali.",
#    'qas': [{'answers': [{'answer_start': 3, 'text': 'sbiancamento'}],
#      'id': '56e76a5800c9c71400d770f3',
#      'question': "Qual è il processo di fabbricazione della carta più legato all' inquinamento?"},
#     {'answers': [{'answer_start': 715, 'text': 'tessuto adiposo'}],
#      'id': '56e76a5800c9c71400d770f5',
#      'question': 'Dove vengono conservate le diossine nelle nostre fonti animali di alimenti?'},
#     {'answers': [{'answer_start': 297,
#        'text': 'la Convenzione di Stoccolma sugli inquinanti organici persistenti'}],
#      'id': '56e76a5800c9c71400d770f6',
#      'question': 'Quale agenzia internazionale regolamenta le diossine a livello internazionale?'}]},
#   {'context': "Alcuni produttori hanno iniziato a utilizzare un' alternativa nuova e molto più ecologica agli imballaggi in plastica espansa. Realizzato in carta e commercialmente noto come schiuma di carta, il nuovo imballaggio ha proprietà meccaniche molto simili a quelle di alcuni imballaggi in plastica espansa, ma è biodegradabile e può anche essere riciclato con carta comune.",
#    'qas': [{'answers': [{'answer_start': 175, 'text': 'schiuma di carta'}],
#      'id': '56e76b5600c9c71400d770fc',
#      'question': "Quale prodotto utilizzato nella vendita di carta è stato recentemente utilizzato dai produttori per essere più rispettoso dell' ambiente?"},
#     {'answers': [{'answer_start': 307, 'text': 'biodegradabile'}],
#      'id': '56e76b5600c9c71400d770fd',
#      'question': "Qual è il principale vantaggio dell' uso della schiuma di carta rispetto alla tradizionale fascia termoretraibile?"},
#     {'answers': [{'answer_start': 141, 'text': 'carta'}],
#      'id': '56e76b5600c9c71400d770fe',
#      'question': 'Di cosa è composta principalmente la schiuma di carta?'}]},
#   {'context': "Con le crescenti preoccupazioni ambientali legate ai rivestimenti sintetici (come il PFOA) e i prezzi più elevati dei prodotti petrolchimici a base di idrocarburi, si concentra l' attenzione sulla zeina (proteina del mais) come rivestimento per la carta in applicazioni ad alto contenuto di grasso come i sacchi di popcorn.",
#    'qas': []}],
#  'title': 'Carta'}

# %%
data_files = {"train": "SQuAD_it-train.json", "test": "SQuAD_it-test.json"}
squad_it_dataset = load_dataset("json", data_files=data_files, field="data")
squad_it_dataset
# Out:
# Downloading and preparing dataset json/default to /root/.cache/huggingface/datasets/json/default-1447cd22838bda75/0.0.0/e347ab1c932092252e717ff3f949105a4dd28b27e842dd53157d2f72e276c2e4...
# Downloading data files:   0%|          | 0/2 [00:00<?, ?it/s]
# Extracting data files:   0%|          | 0/2 [00:00<?, ?it/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# Generating test split: 0 examples [00:00, ? examples/s]
# Dataset json downloaded and prepared to /root/.cache/huggingface/datasets/json/default-1447cd22838bda75/0.0.0/e347ab1c932092252e717ff3f949105a4dd28b27e842dd53157d2f72e276c2e4. Subsequent calls will reuse this data.
#   0%|          | 0/2 [00:00<?, ?it/s]
# DatasetDict({
#     train: Dataset({
#         features: ['paragraphs', 'title'],
#         num_rows: 442
#     })
#     test: Dataset({
#         features: ['paragraphs', 'title'],
#         num_rows: 48
#     })
# })

# %%
data_files = {"train": "SQuAD_it-train.json.gz", "test": "SQuAD_it-test.json.gz"}
squad_it_dataset = load_dataset("json", data_files=data_files, field="data")
# Out:
# Downloading and preparing dataset json/default to /root/.cache/huggingface/datasets/json/default-02ae73504550c953/0.0.0/e347ab1c932092252e717ff3f949105a4dd28b27e842dd53157d2f72e276c2e4...
# Downloading data files:   0%|          | 0/2 [00:00<?, ?it/s]
# Extracting data files:   0%|          | 0/2 [00:00<?, ?it/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# Generating test split: 0 examples [00:00, ? examples/s]
# Dataset json downloaded and prepared to /root/.cache/huggingface/datasets/json/default-02ae73504550c953/0.0.0/e347ab1c932092252e717ff3f949105a4dd28b27e842dd53157d2f72e276c2e4. Subsequent calls will reuse this data.
#   0%|          | 0/2 [00:00<?, ?it/s]

# %%
url = "https://github.com/crux82/squad-it/raw/master/"
data_files = {
    "train": url + "SQuAD_it-train.json.gz",
    "test": url + "SQuAD_it-test.json.gz",
}
squad_it_dataset = load_dataset("json", data_files=data_files, field="data")
# Out:
# Downloading and preparing dataset json/default to /root/.cache/huggingface/datasets/json/default-57dcee3ea6992346/0.0.0/e347ab1c932092252e717ff3f949105a4dd28b27e842dd53157d2f72e276c2e4...
# Downloading data files:   0%|          | 0/2 [00:00<?, ?it/s]
# Downloading data:   0%|          | 0.00/7.73M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/1.05M [00:00<?, ?B/s]
# Extracting data files:   0%|          | 0/2 [00:00<?, ?it/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# Generating test split: 0 examples [00:00, ? examples/s]
# Dataset json downloaded and prepared to /root/.cache/huggingface/datasets/json/default-57dcee3ea6992346/0.0.0/e347ab1c932092252e717ff3f949105a4dd28b27e842dd53157d2f72e276c2e4. Subsequent calls will reuse this data.
#   0%|          | 0/2 [00:00<?, ?it/s]
